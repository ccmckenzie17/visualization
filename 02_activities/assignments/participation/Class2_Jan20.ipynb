# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(613)
x=np.arange(50)
y=np.random.randint(0, 100,50)

fig,ax=plt.subplots(1,1,figsize=(5, 3))
fig.patch.set_facecolor("#e77e7e")

ax.patch.set_facecolor("#7ee793")
ax.tick_params(axis='both', colors='#7ee793')

# %% [markdown]
# Activity 1
#
# Visualization # 1
#
# Nice to look at?
# Yes. This visualization is eye catching although its message is not immediately obvious
#
# Accurate?
# Yes, but bias makes it misleading. Although they do use real gun death data and seem to have some method for predicting life spans the visualization is predictive because we don't actually know how long these individuals would have lived. Some aspects are unclear like what does the height of a line represent. Also does not compare to individuals who died by other means
#
# What's the message?
# That many individuals lives have been cut short by gun violence.
#
# Overall good or bad?
# Mixed. Overall while impactful and accurate the message is muddled by bias and unclear representations.
#
# ---
#
#
# Visualization # 2
#
# Nice to look at?
# Yes. It is clear and not flashy
#
# Accurate?
# Yes. It uses real data from a confirmed source
#
# What's the message?
# Active shooter incidents are increasing in the United States from 2000 to 2015
#
# Overall good or bad?
# Good! Clear and unbiased. Delivers its message very effectively
